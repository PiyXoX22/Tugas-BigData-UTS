# %% [markdown]
# #**Transformasi Data Dengan RDBMS**
#
# ## **Execute SQL statement di platform Google Colab Cell**

# %%
# %load_ext sql

# %%
# %%sql
# sqlite:///retaila.db

# %%
# %%sql
# create table demo(id int, title varchar);
# insert into demo values (1,'pqr'),(2,'stu');
# select * from demo;
# Out:
#  * sqlite:///retaila.db
# (sqlite3.OperationalError) table demo already exists
# [SQL: create table demo(id int, title varchar);]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
#unzip
#!unzip filename.zip
#!mkdir /content/crowdflower
#!mv "/content/text_emotion.csv" "/content/crowdflower/"

# %%
#dataset from original source: https://github.com/rahmadsa/dataset/blob/main/text_emotion.csv
#download overwrite
# !wget -N https://github.com/rahmadsa/dataset/blob/main/text_emotion.csv -P /content/crowdflower/
# Out:
# --2026-05-23 14:44:37--  https://github.com/rahmadsa/dataset/blob/main/text_emotion.csv
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/crowdflower/text_emotion.csv’
#
# text_emotion.csv        [ <=>                ] 220.32K  --.-KB/s    in 0.1s
#
# Last-modified header missing -- time-stamps turned off.
# 2026-05-23 14:44:38 (1.57 MB/s) - ‘/content/crowdflower/text_emotion.csv’ saved [225612]

# %% [markdown]
# ## **Load remote CSV and kedalam SQLITE table**

# %%
# load the remote data into a Pandas DataFrame
import pandas as pd
df_cfemotion = pd.read_csv('https://github.com/rahmadsa/dataset/blob/main/text_emotion.csv?raw=true', on_bad_lines='skip', encoding='latin-1')
df_cfemotion
# Out:
#          tweet_id   sentiment         author  \
# 0      1956967341       empty     xoshayzers
# 1      1956967666     sadness      wannamama
# 2      1956967696     sadness      coolfunky
# 3      1956967789  enthusiasm    czareaquino
# 4      1956968416     neutral      xkilljoyx
# ...           ...         ...            ...
# 39995  1753918954     neutral  showMe_Heaven
# 39996  1753919001        love       drapeaux
# 39997  1753919005        love       JenniRox
# 39998  1753919043   happiness       ipdaman1
# 39999  1753919049        love    Alpharalpha
#
#                                                  content
# 0      @tiffanylue i know  i was listenin to bad habi...
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 3                   wants to hang out with friends SOON!
# 4      @dannycastillo We want to trade with someone w...
# ...                                                  ...
# 39995                                   @JohnLloydTaylor
# 39996                     Happy Mothers Day  All my love
# 39997  Happy Mother's Day to all the mommies out ther...
# 39998  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999  @mopedronin bullet train from tokyo    the gf ...
#
# [40000 rows x 4 columns]

# %%
#connect to sqlite db and send csv data to sqlite table
import sqlite3 as sql
conn = sql.connect('/content/cfemotion.db')
df_cfemotion.to_sql('tb_emotion', conn)
#optional
#ds_cfemotion.to_sql('tb_emotion', conn, if_exists='append', index = False)
# Out:
# 40000

# %%
#connect to sqlite db and read from sqlite table
import sqlite3 as sql
conn = sql.connect('/content/cfemotion.db')
df_cfemotion = pd.read_sql('SELECT * FROM tb_emotion', conn)
df_cfemotion
# Out:
#        index    tweet_id   sentiment         author  \
# 0          0  1956967341       empty     xoshayzers
# 1          1  1956967666     sadness      wannamama
# 2          2  1956967696     sadness      coolfunky
# 3          3  1956967789  enthusiasm    czareaquino
# 4          4  1956968416     neutral      xkilljoyx
# ...      ...         ...         ...            ...
# 39995  39995  1753918954     neutral  showMe_Heaven
# 39996  39996  1753919001        love       drapeaux
# 39997  39997  1753919005        love       JenniRox
# 39998  39998  1753919043   happiness       ipdaman1
# 39999  39999  1753919049        love    Alpharalpha
#
#                                                  content
# 0      @tiffanylue i know  i was listenin to bad habi...
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 3                   wants to hang out with friends SOON!
# 4      @dannycastillo We want to trade with someone w...
# ...                                                  ...
# 39995                                   @JohnLloydTaylor
# 39996                     Happy Mothers Day  All my love
# 39997  Happy Mother's Day to all the mommies out ther...
# 39998  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999  @mopedronin bullet train from tokyo    the gf ...
#
# [40000 rows x 5 columns]

# %% [markdown]
# ## **Loading GoEmotion Dataset ke database Sqlite**

# %%
# !wget -P /content/ https://archive.org/download/goemotions/goemotions_1.csv
# !wget -P /content/ https://archive.org/download/goemotions/goemotions_2.csv
# !wget -P /content/ https://archive.org/download/goemotions/goemotions_3.csv
# Out:
# --2026-05-23 14:44:53--  https://archive.org/download/goemotions/goemotions_1.csv
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dn721608.ca.archive.org/0/items/goemotions/goemotions_1.csv [following]
# --2026-05-23 14:44:54--  https://dn721608.ca.archive.org/0/items/goemotions/goemotions_1.csv
# Resolving dn721608.ca.archive.org (dn721608.ca.archive.org)... 204.62.247.27
# Connecting to dn721608.ca.archive.org (dn721608.ca.archive.org)|204.62.247.27|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14174600 (14M) [text/csv]
# Saving to: ‘/content/goemotions_1.csv’
#
# goemotions_1.csv    100%[===================>]  13.52M  8.90MB/s    in 1.5s
#
# 2026-05-23 14:44:57 (8.90 MB/s) - ‘/content/goemotions_1.csv’ saved [14174600/14174600]
#
# --2026-05-23 14:44:57--  https://archive.org/download/goemotions/goemotions_2.csv
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dn721608.ca.archive.org/0/items/goemotions/goemotions_2.csv [following]
# --2026-05-23 14:44:57--  https://dn721608.ca.archive.org/0/items/goemotions/goemotions_2.csv
# Resolving dn721608.ca.archive.org (dn721608.ca.archive.org)... 204.62.247.27
# Connecting to dn721608.ca.archive.org (dn721608.ca.archive.org)|204.62.247.27|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14173154 (14M) [text/csv]
# Saving to: ‘/content/goemotions_2.csv’
#
# goemotions_2.csv    100%[===================>]  13.52M  7.61MB/s    in 1.8s
#
# 2026-05-23 14:45:00 (7.61 MB/s) - ‘/content/goemotions_2.csv’ saved [14173154/14173154]
#
# --2026-05-23 14:45:00--  https://archive.org/download/goemotions/goemotions_3.csv
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dn721608.ca.archive.org/0/items/goemotions/goemotions_3.csv [following]
# --2026-05-23 14:45:01--  https://dn721608.ca.archive.org/0/items/goemotions/goemotions_3.csv
# Resolving dn721608.ca.archive.org (dn721608.ca.archive.org)... 204.62.247.27
# Connecting to dn721608.ca.archive.org (dn721608.ca.archive.org)|204.62.247.27|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14395164 (14M) [text/csv]
# Saving to: ‘/content/goemotions_3.csv’
#
# goemotions_3.csv    100%[===================>]  13.73M  8.10MB/s    in 1.7s
#
# 2026-05-23 14:45:04 (8.10 MB/s) - ‘/content/goemotions_3.csv’ saved [14395164/14395164]

# %%
# load the remote data into a Pandas DataFrame
import pandas as pd
df_goemotions1 = pd.read_csv('https://github.com/rahmadsa/dataset/blob/main/goemotions_1.csv', on_bad_lines='skip', encoding='latin-1')
df_goemotions1[1:3]
# Out:
#                                      <!DOCTYPE html>
# 1                                          lang="en"
# 2    data-color-mode="auto" data-light-theme="lig...

# %%
# load the remote data into a Pandas DataFrame
import pandas as pd
df_goemotions2 = pd.read_csv('https://github.com/rahmadsa/dataset/blob/main/goemotions_2.csv', on_bad_lines='skip', encoding='latin-1')
df_goemotions2[1:3]
# Out:
#                                      <!DOCTYPE html>
# 1                                          lang="en"
# 2    data-color-mode="auto" data-light-theme="lig...

# %%
# load the remote data into a Pandas DataFrame
import pandas as pd
df_goemotions3 = pd.read_csv('https://github.com/rahmadsa/dataset/blob/main/goemotions_3.csv', on_bad_lines='skip', encoding='latin-1')
df_goemotions3[1:3]
# Out:
#                                      <!DOCTYPE html>
# 1                                          lang="en"
# 2    data-color-mode="auto" data-light-theme="lig...

# %%
#connect to sqlite db and send csv data to sqlite table
import sqlite3 as sql
conn = sql.connect('/content/goemotions.db')

df_goemotions1.to_sql('tb_goemotions', conn, if_exists='append', index = False)
df_goemotions2.to_sql('tb_goemotions', conn, if_exists='append', index = False)
df_goemotions3.to_sql('tb_goemotions', conn, if_exists='append', index = False)
# Out:
# 1050

# %%
#connect to sqlite db and read from sqlite table
import sqlite3 as sql
conn = sql.connect('/content/goemotions.db')
df_goemotions = pd.read_sql('SELECT * FROM tb_goemotions', conn)
df_goemotions
# Out:
#                                         <!DOCTYPE html>
# 0                                                 <html
# 1                                             lang="en"
# 2       data-color-mode="auto" data-light-theme="lig...
# 3       data-a11y-animated-images="system" data-a11y...
# 4                                                     >
# ...                                                 ...
# 3145                                             </div>
# 3146      <div id="js-global-screen-reader-notice" c...
# 3147      <div id="js-global-screen-reader-notice-as...
# 3148                                            </body>
# 3149                                            </html>
#
# [3150 rows x 1 columns]

# %% [markdown]
# ##**Import Database File Sqlite**
#
# Mengunduh suatu berkas dari internet adalah hal yang umum, baik untuk data backup, pengunduhan laporan, atau mengambil sumber data untuk analisis. Pengunduhan berkas dapat dilakukan secara manual satu per satu. Kita dapat menyederhanakan prosesnya dengan mengotomatiskannya menggunakan pemrograman Python.
#
# Sebagai contoh kita akan mengunduh file dengan URL sebagai berikut:
#
# https://github.com/rahmadsa/dataset/blob/main/Car_Database.db
#
# Berikut adalah contoh potongan script untuk mengunduh data dari suatu URL di internet. File download akan di simpan pada folder '/content/' pada colabs folder

# %%
import requests
#URL file
path = "https://github.com/rahmadsa/dataset/raw/refs/heads/main/Car_Database.db"

req = requests.get(path, stream=True)
url_content = req.content

db_file_name = 'Car_Database.db'
db_file = open(db_file_name, 'wb')

db_file.write(url_content)
db_file.close()

# %% [markdown]
# ##**Check Database File Sqlite**
#
# Untuk melihat daftar tabel dari suatu database SQLite, kita bisa menggunakan perintah ‘.tables’ jika berinteraksi melalui shell baris perintah sqlite3.
#
# Kita bisa menggunakan kueri pada tabel sqlite_master dengan “SELECT name FROM sqlite_master WHERE type=’table’;”. Di sinilah SQLite menyimpan metadata tentang semua tabel di database kita

# %%
import sqlite3

#folder file pada google drive
folder = '/content/'
namafileDB = 'Car_Database.db'
conn = sqlite3.connect(folder+namafileDB)  # Replace 'your_database.db' with the actual database file name
cursor = conn.cursor()

#check table - table dalam suatu database
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")

results = cursor.fetchall()
for row in results:
    print(row)
# Out:
# ('Customers',)
# ('sqlite_sequence',)
# ('Models',)
# ('Customer_Ownership',)
# ('Dealer_Brand',)
# ('Car_Parts',)
# ('Manufacture_Plant',)
# ('Brands',)
# ('Dealers',)
# ('Car_Options',)
# ('Car_Vins',)

# %% [markdown]
# Untuk melihat data salah satu table pada salah satu table menggunakan perintah sebagai berikut.

# %%
#check isi salah satu table dalam database
print("Daftar isi Tabel Model : ")
cursor.execute("SELECT * FROM Models LIMIT 10")
results = cursor.fetchall()
for row in results:
    print(row)

conn.close()
# Out:
# Daftar isi Tabel Model :
# (1, 'The Blonde', 23000, 1)
# (2, 'The Brunette', 25000, 1)
# (3, 'The Red Head', 29000, 1)
# (4, 'Hat', 22000, 2)
# (5, 'Sweater', 25000, 2)
# (6, 'T-Shirt', 27000, 2)
# (7, 'Orange', 15000, 3)
# (8, 'Blue', 12000, 3)
# (9, 'Green', 17000, 3)
# (10, 'LaFerrari', 125000, 4)

# %% [markdown]
# **Tugas Praktek 5a :**
#
# 1. Load dataset dari file CSV
# import pandas as pd
# import sqlite3
#
# # load dataset
# df_yk = pd.read_csv('/content/transaksi_ritel_yk.csv')
# df_mgl = pd.read_csv('/content/transaksi_ritel_mgl.csv')
#
# print(df_yk.shape)
# print(df_mgl.shape)
# 2. Gabungkan dua dataset
# df_all = pd.concat([df_yk, df_mgl], ignore_index=True)
# print("Jumlah baris setelah digabung:", len(df_all))
# df_all.head()
# 3. Cek struktur data
# df_all.info()
# df_all.isnull().sum()
# 4. Bersihkan data
# # ubah kolom tanggal
# df_all['tanggal'] = pd.to_datetime(df_all['tanggal'], format='%d-%m-%Y', errors='coerce')
#
# # buang duplikat
# df_all = df_all.drop_duplicates()
#
# # buang missing value
# df_all = df_all.dropna()
#
# df_all.head()
# 5. Simpan ke SQLite
# conn = sqlite3.connect('/content/retaila.db')
# df_all.to_sql('tb_transaksi_retail', conn, if_exists='replace', index=False)
#
# print("Data berhasil disimpan ke SQLite")
# 6. Cek isi tabel SQLite
# query = "SELECT * FROM tb_transaksi_retail LIMIT 10"
# df_sql = pd.read_sql_query(query, conn)
# df_sql
# 7. Cek jumlah data di SQLite
# query = "SELECT COUNT(*) AS jumlah_baris FROM tb_transaksi_retail"
# pd.read_sql_query(query, conn)
#
# **Tugas Praktek 5b :**
#
# 1. Hitung jumlah data per area
# query = """
# SELECT area, COUNT(*) AS jumlah_data
# FROM tb_transaksi_retail
# GROUP BY area
# """
# pd.read_sql_query(query, conn)
# 2. Hitung total penjualan per produk
# query = """
# SELECT nama, SUM(jumlah) AS total_terjual
# FROM tb_transaksi_retail
# GROUP BY nama
# ORDER BY total_terjual DESC
# """
# pd.read_sql_query(query, conn)
# 3. Filter produk tertentu: Biskuit Waver Kaleng
# query = """
# SELECT *
# FROM tb_transaksi_retail
# WHERE nama = 'Biskuit Waver Kaleng'
# """
# df_biskuit = pd.read_sql_query(query, conn)
# df_biskuit
# 4. Visualisasi penjualan bulanan produk tertentu
# # pastikan kolom tanggal sudah datetime
# df_all['bulan'] = df_all['tanggal'].dt.month
#
# produk = 'Biskuit Waver Kaleng'
# df_produk = df_all[df_all['nama'] == produk]
#
# monthly_sales = df_produk.groupby('bulan')['jumlah'].sum().reindex(range(1, 13), fill_value=0)
#
# import matplotlib.pyplot as plt
#
# plt.figure(figsize=(10,5))
# plt.plot(monthly_sales.index, monthly_sales.values, marker='o')
# plt.xticks(range(1,13))
# plt.xlabel('Bulan')
# plt.ylabel('Jumlah Terjual')
# plt.title(f'Penjualan Bulanan {produk}')
# plt.grid(True)
# plt.show()

# %% [markdown]
# **Jawab :**
#
# ..
